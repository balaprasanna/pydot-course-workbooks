# %%
import seaborn as sns

# %%
df = sns.load_dataset("tips")

# %%
from ipywidgets.widgets import interact

# %%
day =list(df.day.unique())

@interact
def filter_day(day=day):
    return df[df.day == day]
# Out:
# interactive(children=(Dropdown(description='day', options=('Sun', 'Sat', 'Thur', 'Fri'), value='Sun'), Output(…

# %%
day =list(df.day.unique())
time =list(df.time.unique())
size =list(df['size'].unique())

@interact
def filter_day(day=day,time=time,size=size):
    subset = df[(df.day == day)&(df.time==time)&(df['size']==size)]
    sns.scatterplot(x="total_bill",y="tip",data=subset)
    return subset.head()
# Out:
# interactive(children=(Dropdown(description='day', options=('Sun', 'Sat', 'Thur', 'Fri'), value='Sun'), Dropdow…

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.heatmap(tips.iloc[:,[0,1]].corr())

# %%
sub = tips.iloc[:,[0,1]]
sns.lmplot(x="total_bill", y="tip",data=sub)

# %%
def get_soup_form_Selenium(url):
    from bs4 import BeautifulSoup
    from selenium import webdriver
    from selenium.webdriver.common.keys import Keys
    drive_location = r"C:\Users\balap\Downloads\Jan 2020\chromedriver.exe"
    driver = webdriver.Chrome(drive_location)
    driver.get(url)
    soup = BeautifulSoup(driver.page_source)
    return soup

# %%
import pandas_datareader.data as web
from datetime import datetime

# %%
start = datetime(2016, 9, 1)
end = datetime(2018, 9, 1)

# %%
f = web.DataReader('AAPL', 'iex', start, end)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-757ae07b6fea> in <module>
# ----> 1 f = web.DataReader('AAPL', 'iex', start, end)
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
#     190     return _deprecate_kwarg
#
# ~\Anaconda3\lib\site-packages\pandas_datareader\data.py in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     397             retry_count=retry_count,
#     398             pause=pause,
# --> 399             session=session,
#     400         ).read()
#     401
#
# ...

# %%
symbol = 'WIKI/AAPL'  # or 'AAPL.US'

df = web.DataReader(symbol, 'quandl', '2015-01-01', '2015-01-05')

df.loc['2015-01-02']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-a0d98c9f958e> in <module>
#       1 symbol = 'WIKI/AAPL'  # or 'AAPL.US'
#       2
# ----> 3 df = web.DataReader(symbol, 'quandl', '2015-01-01', '2015-01-05')
#       4
#       5 df.loc['2015-01-02']
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
#     190     return _deprecate_kwarg
#
# ~\Anaconda3\lib\site-packages\pandas_datareader\data.py in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     505             pause=pause,
#     506             session=session,
# --> 507             api_key=api_key,
#     508         ).read()
# ...

# %%
import http.client

conn = http.client.HTTPSConnection("investors-exchange-iex-trading.p.rapidapi.com")

headers = {
    'x-rapidapi-host': "investors-exchange-iex-trading.p.rapidapi.com",
    'x-rapidapi-key': "9200d3b881msh29252ea0541e2b7p1141d3jsn74dfc535f00c"
    }

conn.request("GET", "/stock/aapl/time-series", headers=headers)

res = conn.getresponse()
data = res.read()

import pandas as pd

# %%
import http.client

conn = http.client.HTTPSConnection("investors-exchange-iex-trading.p.rapidapi.com")

headers = {
    'x-rapidapi-host': "investors-exchange-iex-trading.p.rapidapi.com",
    'x-rapidapi-key': "9200d3b881msh29252ea0541e2b7p1141d3jsn74dfc535f00c"
    }

conn.request("GET", "/stock/msft/time-series", headers=headers)

res = conn.getresponse()
data_msft = res.read()
df_msft = pd.DataFrame(json.loads(data_msft))

# %%
import json
df = pd.DataFrame(json.loads(data))

# %%
df['stock'] = 'AAPL'
df_msft['stock'] = 'MSFT'

# %%
df.head()
# Out:
#    change  changeOverTime  changePercent    close        date    high   label  \
# 0   0.910        0.000000          0.427  214.170  2019-09-09  216.44   Sep 9
# 1   2.530        0.011813          1.181  216.700  2019-09-10  216.78  Sep 10
# 2   6.890        0.043984          3.180  223.590  2019-09-11  223.71  Sep 11
# 3  -0.505        0.041626         -0.226  223.085  2019-09-12  226.42  Sep 12
# 4  -4.335        0.021385         -1.943  218.750  2019-09-13  220.79  Sep 13
#
#       low    open  unadjustedVolume    volume      vwap stock
# 0  211.07  214.84          27309401  27309401  214.9150  AAPL
# 1  211.71  213.86          31777931  31777931  214.3584  AAPL
# 2  217.73  218.07          44289646  44289646  221.4456  AAPL
# 3  222.86  224.80          32226669  32226669  224.6639  AAPL
# 4  217.02  220.00          39763296  39763296  218.8420  AAPL

# %%
final = pd.concat([df, df_msft], axis=0)

# %%
final
# Out:
#     change  changeOverTime  changePercent    close        date      high  \
# 0    0.910        0.000000          0.427  214.170  2019-09-09  216.4400
# 1    2.530        0.011813          1.181  216.700  2019-09-10  216.7800
# 2    6.890        0.043984          3.180  223.590  2019-09-11  223.7100
# 3   -0.505        0.041626         -0.226  223.085  2019-09-12  226.4200
# 4   -4.335        0.021385         -1.943  218.750  2019-09-13  220.7900
# 5    1.150        0.026754          0.526  219.900  2019-09-16  220.1300
# 6    0.800        0.030490          0.364  220.700  2019-09-17  220.8200
# 7    2.070        0.040155          0.938  222.770  2019-09-18  222.8500
# 8   -1.810        0.031704         -0.812  220.960  2019-09-19  223.7600
# 9   -3.230        0.016622         -1.462  217.730  2019-09-20  222.5600
# 10   0.990        0.021245          0.455  218.720  2019-09-23  219.8400
# 11  -1.040        0.016389         -0.475  217.680  2019-09-24  222.4900
# ...
